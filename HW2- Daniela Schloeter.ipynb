# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # E2.
# Finding when a function is increasing/decreasing and concave up/down. When is the function
# f(x) = 2x
# 3 +24x
# 2 −54x decreasing? When is it concave up? Plot the function and find your
# check your answer?.

# %%
x = np.arange(-15, 15, 1)
y= [2*(x**3)+24*(x**2)-54*x for x in x]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Plotting the function' f(x) = 2x^3 +24x^2 −54x'",pad=20)
plt.show()

# %% [markdown]
# The answers match with the graph, from negative infinite to -9 the function increases, from -9 to 1 the function decreases and from 1 to infinite the function increases again.
# -4 is the point of inflection and we can see how the curve changes from concave down to concave up

# %% [markdown]
# # E.3:
# Finding critical points, local max/min, global max/min, and inflection points. Find all critical
# points and inflection points of f(x) = 2x
# 3 +24x
# 2 −54x. Classify the critical points as local min,
# local max, or neither. Find the global max and min of this function on [−3,3] and on (−∞,0).
# Plot the function and find your check your answer?.

# %% [markdown]
# The local min for the previous graph is (1,-28) and match the written results
# The local max for the previous graph is (-9,972) and match the written results
# The global min and max are -infinite and infinite

# %%
x = np.arange(-3, 3, 1)
y= [2*(x**3)+24*(x**2)-54*x for x in x]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Plotting the function ' f(x) = 2x^3 +24x^2 −54x' for the interval [-3,3]",pad=20)
plt.show()

# %% [markdown]
# The global min (1,-28) matches the by hand procedure
# and the global max (-3,324) also matches the by hand procedure

# %%
x = np.arange(-99999, 0, 1)
y= [2*(x**3)+24*(x**2)-54*x for x in x]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Plotting the function ' f(x) = 2x^3 +24x^2 −54x' for the interval (-infinite,0]",pad=20)
plt.show()

x = np.arange(-15, 0, 1)
y= [2*(x**3)+24*(x**2)-54*x for x in x]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Plotting the function ' f(x) = 2x^3 +24x^2 −54x' for the interval (-infinite,0] detailed",pad=20)
plt.show()

# %% [markdown]
# The global min is negative infinite or no global min and it matches the by hand procedure
# and the global max (-9,972) also matches the by hand procedure

# %% [markdown]
# # E.4:
# i. Find the gradient vector of f(x, y) = x
# 2 +y
# 2
# .

# %% [markdown]
# ii. What are the gradient vectors at (1,2),(2,1)and(0,0)? Plot the function in 3D space and
# check your answers?

# %%
from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show


def function(x,y):
 return (x**2+y**2)
 
x = arange(-10,10,1)
y = arange(-10,10,1)
X,Y = meshgrid(x, y) # grid of point
Z = function(X, Y) # evaluation of the function on the grid

im = imshow(Z,cmap=cm.RdBu) # drawing the function
# adding the Contour lines with labels
cset = contour(Z,arange(-1,1.5,0.2),linewidths=2,cmap=cm.Set2)
clabel(cset,inline=True,fmt='%1.1f',fontsize=10)
colorbar(im) # adding the colobar on the right
# latex fashion title
title('Plotting the function x**2+y**2', pad=20)
show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from numpy import sin,sqrt

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, 
                      cmap=cm.RdBu,linewidth=0, antialiased=False)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# # E.5:
#
# i.Find the gradient vector of f(x, y) = 2xy+x^2 +y.

# %% [markdown]
# ii.What are the gradient vectors at (1,1),(0,−1)and(0,0)? Plot the function in 3D space and
# check your answers?

# %%
def function(x,y):
 return (2*x*y+x**2 +y)
 
x = arange(-10,10,1)
y = arange(-10,10,1)
X,Y = meshgrid(x, y) # grid of point
Z = function(X, Y) # evaluation of the function on the grid

im = imshow(Z,cmap=cm.RdBu) # drawing the function
# adding the Contour lines with labels
cset = contour(Z,arange(-1,1.5,0.2),linewidths=2,cmap=cm.Set2)
clabel(cset,inline=True,fmt='%1.1f',fontsize=10)
colorbar(im) # adding the colobar on the right
# latex fashion title
title('Plotting the function x**2+y**2', pad=20)
show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, 
                      cmap=cm.RdBu,linewidth=0, antialiased=False)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# # E.7:
# Find the eigenvalues and eigenvectors of the given matrix by hand and check results by the
# computer (use Python to check your results).

# %% [markdown]
# i.
#
# 2  0
#
# 0  5

# %%
from numpy import linalg as LA
w, v = LA.eig(np.array([[2, 0], [0, 5]]))
print('eigenvalues '+str(w))
print('eigenvectors '+str(v))
# Out:
# eigenvalues [2. 5.]
# eigenvectors [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# ii.
#
# 5 1
#
# 4 5

# %%
w, v = LA.eig(np.array([[5, 1], [4, 5]]))
print('eigenvalues '+str(w))
print('eigenvectors '+str(v))
# Out:
# eigenvalues [7. 3.]
# eigenvectors [[ 0.4472136  -0.4472136 ]
#  [ 0.89442719  0.89442719]]

# %% [markdown]
# iii.
#
# 3 5
#
# 3 1

# %%
w, v = LA.eig(np.array([[3, 5], [3, 1]]))
print('eigenvalues '+str(w))
print('eigenvectors '+str(v))
# Out:
# eigenvalues [ 6. -2.]
# eigenvectors [[ 0.85749293 -0.70710678]
#  [ 0.51449576  0.70710678]]

# %% [markdown]
# For each result the eigen values are the same as the written calculations but the eigenvectors vary. This is explained by the fact that python normalizes while we don't

# %% [markdown]
# # E.9:
# Which of the following sets of vectors are independent? Find the dimension of the vector space
# spanned by each set. (Verify your answers using Python).)

# %% [markdown]
# i.
# 
# 
# 1
# 2
# 3
# 
# ,
# 
# 
# 1
# 0
# 1
# 
# ,
# 
# 
# 1
# 2
# 1
# 
# 

# %%
import numpy as np 

# define matrix A using Numpy arrays 
A = np.array([[1, 1, 1], [2, 0, 2], [3, 1, 1]]) 
#define matrix B 
B = np.array([0, 0, 0]) 
# linalg.solve is the function of NumPy to solve a system of linear scalar equations 
print ("Solutions:\n",np.linalg.solve(A, B ) )
print('\nThe vectors are linearly independent \n')
print('Dimensions: '+str(len(np.linalg.solve(A, B ))))
# Out:
# Solutions:
#  [0. 0. 0.]
#
# The vectors are linearly independent
#
# Dimensions: 3

# %% [markdown]
# ii. sin(t), cos(t), cos(2t)

# %%
print('By replacing t with values we can find the answers \n If t=0, t=pi/2 and t=pi:')
# define matrix A using Numpy arrays 
A = np.array([[0,1,1], [1,0,-1], [0,-1,1]]) 
#define matrix B 
B = np.array([0, 0, 0]) 
# linalg.solve is the function of NumPy to solve a system of linear scalar equations 
print ("Solutions:\n",np.linalg.solve(A, B ) )
print('\nThe vectors are linearly independent \n')
print('Dimensions: '+str(len(np.linalg.solve(A, B ))))
# Out:
# By replacing t with values we can find the answers
#  If t=0, t=pi/2 and t=pi:
# Solutions:
#  [0. 0. 0.]
#
# The vectors are linearly independent
#
# Dimensions: 3

# %% [markdown]
# iii. 1+t, 1−t

# %%
print('By replacing t with values we can find the answers \n If t=1, and t=2 ')
# define matrix A using Numpy arrays 
A = np.array([[2,0], [3,-1]]) 
#define matrix B 
B = np.array([0, 0]) 
# linalg.solve is the function of NumPy to solve a system of linear scalar equations 
print ("Solutions:\n",np.linalg.solve(A, B ) )
print('\nThe vectors are linearly independent \n')
print('Dimensions: '+str(len(np.linalg.solve(A, B ))))
# Out:
# By replacing t with values we can find the answers
#  If t=1, and t=2
# Solutions:
#  [0. 0.]
#
# The vectors are linearly independent
#
# Dimensions: 2

# %% [markdown]
# iv.
# 
# 
# 
# 
# 1
# 2
# 2
# 1
# 
# 
# 
# 
# ,
# 
# 
# 
# 
# 1
# 0
# 0
# 1
# 
# 
# 
# 
# ,
# 
# 
# 
# 
# 3
# 4
# 4
# 3
# 
# 
# 

# %%
# define matrix A using Numpy arrays 
A = np.array([[1,1,3], [2,0,4], [2,0,4],[1,1,3]]) 
#define matrix B 
B = np.array([0,0,0,0]) 
# linalg.solve is the function of NumPy to solve a system of linear scalar equations 
print ("Solutions:\n",np.linalg.solve(A, B ) )
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-114-a353537d9d7e> in <module>()
#       4 B = np.array([0,0,0,0])
#       5 # linalg.solve is the function of NumPy to solve a system of linear scalar equations
# ----> 6 print ("Solutions:\n",np.linalg.solve(A, B ) )
#
# /anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     375     a, _ = _makearray(a)
#     376     _assertRankAtLeast2(a)
# --> 377     _assertNdSquareness(a)
#     378     b, wrap = _makearray(b)
#     379     t, result_t = _commonType(a, b)
#
# /anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in _assertNdSquareness(*arrays)
#     209     for a in arrays:
#     210         if max(a.shape[-2:]) != min(a.shape[-2:]):
# --> 211             raise LinAlgError('Last 2 dimensions of the array must be square')
#     212
#     213 def _assertFinite(*arrays):
#
# ...

# %%
print('c3 can be any value \nc2=-c3 \nc1=-2c3 \nThere is not a unique solution for the value of our incognitas, and they are not 0. \nThe vectors are linearly dependent')
# Out:
# c3 can be any value
# c2=-c3
# c1=-2c3
# There is not a unique solution for the value of our incognitas, and they are not 0.
# The vectors are linearly dependent
